# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
import numpy as np

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')

plt.axis([0, 6, 0, 20])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
